# %%
import sys; sys.path.insert(0,'../../../mySoftware/MySoftwarePackage/mac'); from plot_tools import *
# %matplotlib inline

# %% [markdown]
# # cardigraphic plot definition

# %%
def produce_cardiographic_plot( R = 2 , dR = 0.1 , frac = 0.01):
    sample_no , Np , Nn , NN = [] , [] , [] , []
    print 'producing data for cardiographic plot for %.2f < R < %.2f fm, taking %.3f of the configurations'%(R-dR,R+dR,frac)
    i = 0
    for nucleus in nuclei:
        Nucleons = nucleus[np.abs(nucleus.R - R)<dR]
        Nprotons = len(Nucleons[Nucleons.type=='proton'])
        Nneutrons = len(Nucleons[Nucleons.type=='neutron'])
        NNucleons = len(Nucleons)

        sample_no.append(i)
        Np.append(Nprotons)
        Nn.append(Nneutrons)
        NN.append(NNucleons)
        if ((i%1000)==0): 
            print 'nucleus:',i
        i = i+1
    density = pd.DataFrame( {'Sample No.':sample_no , 'Nprotons':Np , 'Nneutrons':Nn , 'NNucleons':NN} )
    print 'done, returning.'
    return density 

def plot_cardiographic_plot( density , R = 2 , dR = 0.1 , particles = 'protons' , color='blue'):
    with sns.axes_style("white"):
        g = sns.JointGrid(x=density['Sample No.'], y=density['N%s'%particles],
                          xlim=(0,len(density)),
                          ylim=(density['N%s'%particles].min()-1,density['N%s'%particles].max()+1))
        g.ax_marg_x.hist(density['Sample No.'],histtype='step',linewidth=0.01)
        g.ax_marg_y.hist(density['N%s'%particles], orientation="horizontal",color=color)
        g.plot_joint(sns.regplot,color='blue')
        g.set_axis_labels('configuration','# %s'%particles)
        g.fig.suptitle('%s, %.2f < R < %.2f fm'%(particles,R-dR,R+dR),fontsize=20)
        g.fig.set_figsize(figsize=(10,10))


def three_cardiographic_plots( density , R = 2 , dR = 0.1 ):
    plot_cardiographic_plot( density , R=R , dR=dR , particles='protons' , color='blue' )
    plot_cardiographic_plot( density , R=R , dR=dR , particles='neutrons' , color='green' )
    plot_cardiographic_plot( density , R=R , dR=dR , particles='Nucleons' , color='black' )

# %% [markdown]
# # load data
# take Massimo configuations and add some variables, that are generated using
#
# python mac/calc_massi_configurations.py --option=read -evf=0.001 -p1 -v3

# %%
configurations = pd.read_csv('/Users/erezcohen/Desktop/DensityFluctuations/anafiles/pb208-ico3-skin-10k.csv')

# %%
nuclei = []
for i in xrange(int(len(configurations.groupby('nucleus_counter')))):
    nucleus = configurations[configurations.nucleus_counter==i]
    nuclei.append(nucleus)
    if (i%1000==0): print 'i:',i
print 'done, len(nuclei):',len(nuclei)
# Out:
# i: 0
# i: 1000
# i: 2000
# i: 3000
# i: 4000
# i: 5000
# i: 6000
# i: 7000
# i: 8000
# i: 9000
# done, len(nuclei): 10000

# %% [markdown]
# NN-distances data. Takes a lot of time to read so don't use by default...

# %%
pp_distances = pd.read_csv('/Users/erezcohen/Desktop/DensityFluctuations/anafiles/pb208-ico3-skin-10k_pp.csv')
pn_distances = pd.read_csv('/Users/erezcohen/Desktop/DensityFluctuations/anafiles/pb208-ico3-skin-10k_pn.csv')
nn_distances = pd.read_csv('/Users/erezcohen/Desktop/DensityFluctuations/anafiles/pb208-ico3-skin-10k_nn.csv')
NN_distances = pd.read_csv('/Users/erezcohen/Desktop/DensityFluctuations/anafiles/pb208-ico3-skin-10k_NN_all.csv')

# %% [markdown]
# # single - body
# lets look on the single-body density as a function of the distance from the center of the nucleus

# %%
# WS distribution
R = np.linspace(0,14,100)
R_0_p , a_p , Np = 6.68  , 0.447 , 82
R_0_n , a_n , Nn = 6.7 , 0.55 , 126
rho_0 = 0.16 
rho_WS_p = [rho_0*(float(Np)/(Np+Nn))/(1+exp((R[i]-R_0_p)/a_p)) for i in range(len(R))]
rho_WS_n = [rho_0*(float(Nn)/(Np+Nn))/(1+exp((R[i]-R_0_n)/a_n)) for i in range(len(R))]
rho_WS_all = [rho_WS_p[i] + rho_WS_n[i] for i in range(len(R))]

# %%
fig, ax = plt.subplots(figsize=(15,10))
neutrons , protons = configurations[configurations['type']=='neutron'] , configurations[configurations['type']=='proton']
N = len(configurations)/float(len(configurations.groupby('nucleus_counter')))*82
print 'normalization:',N
bins = np.linspace(0,14,100)
hp,bins,_ = plt.hist(protons.R , weights=1./(N*protons.R*protons.R) , bins=bins, histtype='step', label='protons',linewidth=2);
hn,bins,_ = plt.hist(neutrons.R , weights=1./(N*neutrons.R*neutrons.R) , bins=bins, histtype='step' , label='neutrons',linewidth=2);
hN,bins,_ = plt.hist(configurations.R , weights=1./(N*configurations.R*configurations.R) , bins=bins, histtype='step', label='all',linewidth=2);
plt.plot(R , rho_WS_all , label='WS', color='black',linewidth=2);
set_axes(ax,'distance from the nucleus center [fm]','$\\rho$ [fm$^{-3}$]')
plt.legend(fontsize=25)
# normalization
integrand_p = [4*3.1415*bins[i]*bins[i]*(bins[i+1]-bins[i])*hp[i] for i in range(len(bins)-1)]
print "protons:",sum(integrand_p)
integrand_n = [4*3.1415*bins[i]*bins[i]*(bins[i+1]-bins[i])*hn[i] for i in range(len(bins)-1)]
print "neutrons:",sum(integrand_n)
integrand_N = [4*3.1415*bins[i]*bins[i]*(bins[i+1]-bins[i])*hN[i] for i in range(len(bins)-1)]
print "nucleons:",sum(integrand_N)
# Out:
# normalization: 17056.0
# protons: 82.8356262438
# neutrons: 127.341712636
# nucleons: 210.177338879

# %% [markdown]
# # two - body
# collect all nucleons from each nucleus and calculate the inter-nucleon distances

# %%
fig, ax = plt.subplots(figsize=(10,10))
N = len(configurations)/float(len(configurations.groupby('nucleus_counter')))*82
print 'normalization:',N
bins = np.linspace(0,14,100)
plt.hist(pp_distances['r(pp)'] , weights=1./(N*pp_distances['r(pp)']*pp_distances['r(pp)']) , bins=bins, histtype='step' , label='p-p',linewidth=2);
plt.hist(nn_distances['r(nn)'] , weights=1./(N*nn_distances['r(nn)']*nn_distances['r(nn)']) , bins=bins, histtype='step' , label='n-n',linewidth=2);
plt.hist(pn_distances['r(pn)'] , weights=1./(N*pn_distances['r(pn)']*pn_distances['r(pn)']) , bins=bins, histtype='step' , label='p-n',linewidth=2);
plt.hist(NN_distances['r(NN)'] , weights=1./(N*NN_distances['r(NN)']*NN_distances['r(NN)']) , bins=bins, histtype='step' , label='N-N (all)',linewidth=2);

set_axes(ax,'$r_{12}$ [fm]','$\\rho^{(2)} (r_{12})$ [fm$^{-3}$]')
plt.legend(fontsize=25)
# Out:
# normalization: 17056.0

# %%
dR , frac  = 0.1 , 1
density_2fm = produce_cardiographic_plot( R = 2 , dR = dR , frac = frac )
density_4fm = produce_cardiographic_plot( R = 4 , dR = dR , frac = frac )
density_6fm = produce_cardiographic_plot( R = 6 , dR = dR , frac = frac )
density_8fm = produce_cardiographic_plot( R = 8 , dR = dR , frac = frac )
# Out:
# producing data for cardiographic plot for 1.90 < R < 2.10 fm, taking 1.000 of the configurations
# nucleus: 0
# nucleus: 1000
# nucleus: 2000
# nucleus: 3000
# nucleus: 4000
# nucleus: 5000
# nucleus: 6000
# nucleus: 7000
# nucleus: 8000
# nucleus: 9000
# done, returning.
# producing data for cardiographic plot for 3.90 < R < 4.10 fm, taking 1.000 of the configurations
# nucleus: 0
# nucleus: 1000
# nucleus: 2000
# nucleus: 3000
# nucleus: 4000
# nucleus: 5000
# nucleus: 6000
# nucleus: 7000
# nucleus: 8000
# nucleus: 9000
# done, returning.
# producing data for cardiographic plot for 5.90 < R < 6.10 fm, taking 1.000 of the configurations
# nucleus: 0
# nucleus: 1000
# nucleus: 2000
# nucleus: 3000
# nucleus: 4000
# nucleus: 5000
# nucleus: 6000
# nucleus: 7000
# nucleus: 8000
# nucleus: 9000
# done, returning.
# producing data for cardiographic plot for 7.90 < R < 8.10 fm, taking 1.000 of the configurations
# nucleus: 0
# nucleus: 1000
# nucleus: 2000
# nucleus: 3000
# nucleus: 4000
# nucleus: 5000
# nucleus: 6000
# nucleus: 7000
# nucleus: 8000
# nucleus: 9000
# done, returning.

# %%
three_cardiographic_plots( density_2fm , 2 , 0.1 )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-22f8a26c71b5> in <module>()
# ----> 1 three_cardiographic_plots( density_2fm , 2 , 0.1 )
#
# <ipython-input-32-8d8437463074> in three_cardiographic_plots(density, R, dR)
#      34
#      35 def three_cardiographic_plots( density , R = 2 , dR = 0.1 ):
# ---> 36     plot_cardiographic_plot( density , R=R , dR=dR , particles='protons' , color='blue' )
#      37     plot_cardiographic_plot( density , R=R , dR=dR , particles='neutrons' , color='green' )
#      38     plot_cardiographic_plot( density , R=R , dR=dR , particles='Nucleons' , color='black' )
#
# <ipython-input-32-8d8437463074> in plot_cardiographic_plot(density, R, dR, particles, color)
#      30         g.set_axis_labels('configuration','# %s'%particles)
#      31         g.fig.suptitle('%s, %.2f < R < %.2f fm'%(particles,R-dR,R+dR),fontsize=20)
# ---> 32         g.fig.se_figsize(figsize=(10,10))
#      33
#      34
#
# AttributeError: 'Figure' object has no attribute 'se_figsize'

# %%
three_cardiographic_plots( density_4fm , 4 , 0.1 )

# %%
three_cardiographic_plots( density_6fm , 6 , 0.1 )

# %%
three_cardiographic_plots( density_8fm , 8 , 0.1 )

# %%
density_2fm.to_csv('/Users/erezcohen/Desktop/DensityFluctuations/anafiles/pb208-ico3-skin-10k_density_2fm.csv')
density_4fm.to_csv('/Users/erezcohen/Desktop/DensityFluctuations/anafiles/pb208-ico3-skin-10k_density_4fm.csv')
density_6fm.to_csv('/Users/erezcohen/Desktop/DensityFluctuations/anafiles/pb208-ico3-skin-10k_density_6fm.csv')
density_8fm.to_csv('/Users/erezcohen/Desktop/DensityFluctuations/anafiles/pb208-ico3-skin-10k_density_8fm.csv')
