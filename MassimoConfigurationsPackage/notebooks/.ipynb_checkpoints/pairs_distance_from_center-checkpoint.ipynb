# %%
import sys; sys.path.insert(0,'../../../mySoftware/MySoftwarePackage/mac'); from plot_tools import *
anafiles_dir = '/Users/erezcohen/Desktop/DensityFluctuations/AnaFiles/csv_files'
# %matplotlib inline
from matplotlib.ticker import NullFormatter

# %%
generic = lambda x: ast.literal_eval(x)

# %% [markdown]
# # load data

# %%
distances = pd.read_csv('/Users/erezcohen/Desktop/DensityFluctuations/anafiles/c12-ico6-10k_rd200_1fm_pairs_distance.csv'
                       ,converters={'NN < 1.0 fm':generic,'pp < 1.0 fm':generic,'nn < 1.0 fm':generic,'np < 1.0 fm':generic})

# %%
distances
# Out:
#                                            NN < 1.0 fm  \
# 0                                                -9999
# 1                       [3.15875148773, 3.15875148773]
# 2                                                -9999
# 3                       [4.59962701797, 4.59962701797]
# 4                                                -9999
# 5                       [4.08987760544, 4.08987760544]
# 6                                                -9999
# 7                       [3.43206810951, 3.43206810951]
# 8                       [4.19398164749, 4.19398164749]
# 9                       [5.60592269897, 5.60592269897]
# 10                                               -9999
# 11                                               -9999
# 12                      [4.17678117752, 4.17678117752]
# 13                                               -9999
# 14                                               -9999
# 15                      [3.00401329994, 3.00401329994]
# 16                                               -9999
# 17                                               -9999
# 18                      [3.14881539345, 3.14881539345]
# 19                                               -9999
# 20   [4.20740461349, 4.20740461349, 3.32704997063, ...
# 21                      [2.08216261864, 2.08216261864]
# 22                      [4.33970546722, 4.33970546722]
# 23                      [2.21286082268, 2.21286082268]
# 24                      [3.53675699234, 3.53675699234]
# 25   [3.52598834038, 3.10054898262, 3.10054898262, ...
# 26   [2.091776371, 6.40529727936, 2.091776371, 6.40...
# 27                                               -9999
# 28                                               -9999
# 29                      [5.88109540939, 5.88109540939]
# ..                                                 ...
# 970  [3.30866622925, 5.18147659302, 3.30866622925, ...
# 971  [2.36053514481, 2.36053514481, 3.64126801491, ...
# 972                                              -9999
# 973                     [1.32582378387, 1.32582378387]
# 974                                              -9999
# 975                                              -9999
# 976                     [3.14599847794, 3.14599847794]
# 977                     [4.07951688766, 4.07951688766]
# 978                                              -9999
# 979                     [4.46079540253, 4.46079540253]
# 980                                              -9999
# 981                                              -9999
# 982                       [3.0577878952, 3.0577878952]
# 983                                              -9999
# 984                                              -9999
# 985                     [3.59927725792, 3.59927725792]
# 986                     [6.07817077637, 6.07817077637]
# 987                       [5.2320318222, 5.2320318222]
# 988                     [5.67730855942, 5.67730855942]
# 989                     [2.33541893959, 2.33541893959]
# 990  [2.55959439278, 2.55959439278, 4.85194349289, ...
# 991                     [2.88169360161, 2.88169360161]
# 992                                              -9999
# 993                     [4.58283996582, 4.58283996582]
# 994                                              -9999
# 995                                              -9999
# 996                     [3.42082571983, 3.42082571983]
# 997                                              -9999
# 998                     [4.25546693802, 4.25546693802]
# 999  [4.22491264343, 2.4939250946, 4.22491264343, 2...
#
#                                            nn < 1.0 fm  \
# 0                                                -9999
# 1                                                -9999
# 2                                                -9999
# 3                       [4.59962701797, 4.59962701797]
# 4                                                -9999
# 5                                                -9999
# 6                                                -9999
# 7                       [3.43206810951, 3.43206810951]
# 8                                                -9999
# 9                                                -9999
# 10                                               -9999
# 11                                               -9999
# 12                                               -9999
# 13                                               -9999
# 14                                               -9999
# 15                                               -9999
# 16                                               -9999
# 17                                               -9999
# 18                                               -9999
# 19                                               -9999
# 20                      [4.20740461349, 4.20740461349]
# 21                                               -9999
# 22                      [4.33970546722, 4.33970546722]
# 23                                               -9999
# 24                                               -9999
# 25                                               -9999
# 26                      [6.40529727936, 6.40529727936]
# 27                                               -9999
# 28                                               -9999
# 29                                               -9999
# ..                                                 ...
# 970                     [5.18147659302, 5.18147659302]
# 971                     [3.64126801491, 3.64126801491]
# 972                                              -9999
# 973                                              -9999
# 974                                              -9999
# 975                                              -9999
# 976                                              -9999
# 977                                              -9999
# 978                                              -9999
# 979                                              -9999
# 980                                              -9999
# 981                                              -9999
# 982                       [3.0577878952, 3.0577878952]
# 983                                              -9999
# 984                                              -9999
# 985                                              -9999
# 986                     [6.07817077637, 6.07817077637]
# 987                                              -9999
# 988                                              -9999
# 989                                              -9999
# 990                     [2.55959439278, 2.55959439278]
# 991                                              -9999
# 992                                              -9999
# 993                     [4.58283996582, 4.58283996582]
# 994                                              -9999
# 995                                              -9999
# 996                                              -9999
# 997                                              -9999
# 998                                              -9999
# 999  [4.22491264343, 2.4939250946, 4.22491264343, 2...
#
#                                            np < 1.0 fm  \
# 0                                                -9999
# 1                       [3.15875148773, 3.15875148773]
# 2                                                -9999
# 3                                                -9999
# 4                                                -9999
# 5                       [4.08987760544, 4.08987760544]
# 6                                                -9999
# 7                                                -9999
# 8                       [4.19398164749, 4.19398164749]
# 9                                                -9999
# 10                                               -9999
# 11                                               -9999
# 12                      [4.17678117752, 4.17678117752]
# 13                                               -9999
# 14                                               -9999
# 15                      [3.00401329994, 3.00401329994]
# 16                                               -9999
# 17                                               -9999
# 18                      [3.14881539345, 3.14881539345]
# 19                                               -9999
# 20                      [3.32704997063, 3.32704997063]
# 21                                               -9999
# 22                                               -9999
# 23                                               -9999
# 24                                               -9999
# 25   [3.52598834038, 3.10054898262, 3.10054898262, ...
# 26                                               -9999
# 27                                               -9999
# 28                                               -9999
# 29                      [5.88109540939, 5.88109540939]
# ..                                                 ...
# 970                                              -9999
# 971                                              -9999
# 972                                              -9999
# 973                     [1.32582378387, 1.32582378387]
# 974                                              -9999
# 975                                              -9999
# 976                                              -9999
# 977                                              -9999
# 978                                              -9999
# 979                     [4.46079540253, 4.46079540253]
# 980                                              -9999
# 981                                              -9999
# 982                                              -9999
# 983                                              -9999
# 984                                              -9999
# 985                     [3.59927725792, 3.59927725792]
# 986                                              -9999
# 987                       [5.2320318222, 5.2320318222]
# 988                     [5.67730855942, 5.67730855942]
# 989                                              -9999
# 990                     [4.85194349289, 4.85194349289]
# 991                     [2.88169360161, 2.88169360161]
# 992                                              -9999
# 993                                              -9999
# 994                                              -9999
# 995                                              -9999
# 996                     [3.42082571983, 3.42082571983]
# 997                                              -9999
# 998                     [4.25546693802, 4.25546693802]
# 999                                              -9999
#
#                         pp < 1.0 fm
# 0                             -9999
# 1                             -9999
# 2                             -9999
# 3                             -9999
# 4                             -9999
# 5                             -9999
# 6                             -9999
# 7                             -9999
# 8                             -9999
# 9    [5.60592269897, 5.60592269897]
# 10                            -9999
# 11                            -9999
# 12                            -9999
# 13                            -9999
# 14                            -9999
# 15                            -9999
# 16                            -9999
# 17                            -9999
# 18                            -9999
# 19                            -9999
# 20                            -9999
# 21   [2.08216261864, 2.08216261864]
# 22                            -9999
# 23   [2.21286082268, 2.21286082268]
# 24   [3.53675699234, 3.53675699234]
# 25                            -9999
# 26       [2.091776371, 2.091776371]
# 27                            -9999
# 28                            -9999
# 29                            -9999
# ..                              ...
# 970  [3.30866622925, 3.30866622925]
# 971  [2.36053514481, 2.36053514481]
# 972                           -9999
# 973                           -9999
# 974                           -9999
# 975                           -9999
# 976  [3.14599847794, 3.14599847794]
# 977  [4.07951688766, 4.07951688766]
# 978                           -9999
# 979                           -9999
# 980                           -9999
# 981                           -9999
# 982                           -9999
# 983                           -9999
# 984                           -9999
# 985                           -9999
# 986                           -9999
# 987                           -9999
# 988                           -9999
# 989  [2.33541893959, 2.33541893959]
# 990                           -9999
# 991                           -9999
# 992                           -9999
# 993                           -9999
# 994                           -9999
# 995                           -9999
# 996                           -9999
# 997                           -9999
# 998                           -9999
# 999                           -9999
#
# [1000 rows x 4 columns]

# %% [markdown]
# NN-distances data. Takes a lot of time to read so don't use by default...

# %%
# a plot to send Massi
d = 1.0 # fm
fig,ax = plt.subplots(figsize=(20,10))
bins = np.linspace(-1,6,21)
for i,(pair_type,color) in enumerate(zip(['pp','nn','np','NN'],['blue'])):
#     zip(['pp','nn','np','NN'],['blue','red','black','teal'])):
    array = []
    for x in np.concatenate([(distances[pair_type+' < %.1f fm'%d]).ravel()]):
#         print type(x)
        if type(x)==type([0.1,0.2]):
            for x_object in x:
                print x_object
                if x_object!=-9999: array.append(x_i)
        else:
            if x!=-9999: array.append(x)
#     print pair_type
#     print array
    plt.hist( array , bins=bins,color=color, histtype='step',linewidth=2,normed=1)
    average = np.average(array)
    std = np.std(array)
    plt.plot([0,0],[0,0],label=pair_type+', avegrage=%.1f, std=%.1f'%(average,std),linewidth=4,color=color)        
    set_axes(ax,'R [fm]',fontsize=35,xticks=[0,1,2,3,4,5])
    plt.legend(fontsize=25)
    ax.yaxis.set_major_formatter(NullFormatter())
plt.tight_layout()
